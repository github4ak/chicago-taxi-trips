# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score
import pandas as pd
from scipy import stats
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %%
# Do regression on clustered data
# We have 4 clusters 1,2,3,4
# Get 4 sets on data based on these clusters
# On each set apply regression
# Dependent variable speed
# Independent variable time of the day, day of the week

# %%
df_test = pd.read_csv("./merged_2016.csv")
