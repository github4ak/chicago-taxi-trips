# %%
import numpy as np
import pandas as pd
import matplotlib

# %%
def parse_data(file_name):
    df = pd.read_csv(file_name)
    y = df['speed'].to_numpy()
    x = df.iloc[:, 1:]
#     print(len(y))
#     print(df.shape)
#     print(df.dtypes)
#     print(df)
#     print(x)

# %%
parse_data("./speed_day_timeslot.csv")
# Out:
#               speed  constant  day  timeslot
# 0         20.417910         1    1         1
# 1         28.820961         1    1         4
# 2         10.968444         1    1         2
# 3         17.230143         1    1         4
# 4         18.824334         1    1         4
# ...             ...       ...  ...       ...
# 26249510   7.500000         1    7         4
# 26249511   6.660000         1    7         3
# 26249512  12.975000         1    7         4
# 26249513  14.571429         1    7         3
# 26249514   3.600000         1    7         2
#
# [26249515 rows x 4 columns]
#           constant  day  timeslot
# 0                1    1         1
# 1                1    1         4
# 2                1    1         2
# 3                1    1         4
# 4                1    1         4
# ...            ...  ...       ...
# 26249510         1    7         4
# 26249511         1    7         3
# 26249512         1    7         4
# 26249513         1    7         3
# ...
